# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
visitors = pd.read_excel('../data/parkvisitors.xlsx')

# %%
visitors = visitors.drop(columns = ['Unnamed: 0', 'Unnamed: 1'])

# %%
visitors.head(10)
# Out:
#                                           Unnamed: 2           Unnamed: 3  \
# 0                                                NaN                  NaN
# 1                                                NaN                  NaN
# 2  This report will not correctly export to CSV. ...                  NaN
# 3                                                NaN                  NaN
# 4                                                NaN  Recreational Visits
# 5                                          Park Name                 2003
# 6                     Abraham Lincoln Birthplace NHP               211650
# 7                                          Acadia NP              2431062
# 8                                          Adams NHP               215659
# 9                           African Burial Ground NM                  NaN
#
#    Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# ...

# %%
visitors = visitors.drop([0,1,2,3,4])

# %%
visitors
# Out:
#                          Unnamed: 2 Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 5                         Park Name       2003      2004.0      2005.0
# 6    Abraham Lincoln Birthplace NHP     211650    201828.0    190809.0
# 7                         Acadia NP    2431062   2207847.0   2051484.0
# 8                         Adams NHP     215659    239504.0    220467.0
# 9          African Burial Ground NM        NaN         NaN         NaN
# ..                              ...        ...         ...         ...
# 390                      Wupatki NM     266159    247971.0    219480.0
# 391                  Yellowstone NP    3019375   2868317.0   2835651.0
# 392                     Yosemite NP    3378664   3280911.0   3304144.0
# 393      Yukon-Charley Rivers NPRES       5552      4260.0     12784.0
# 394                         Zion NP    2458792   2677342.0   2586665.0
#
#      Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  Unnamed: 10  Unnamed: 11  \
# ...

# %%
new_header = visitors.iloc[0] #grab the first row for the header
visitors = visitors[1:] #take the data less the header row
visitors.columns = new_header #set the header row as the df header

# %%
visitors = visitors.reset_index(drop=True)

# %%
visitors
# Out:
# 5                         Park Name     2003     2004.0     2005.0     2006.0  \
# 0    Abraham Lincoln Birthplace NHP   211650   201828.0   190809.0   200054.0
# 1                         Acadia NP  2431062  2207847.0  2051484.0  2083588.0
# 2                         Adams NHP   215659   239504.0   220467.0   225318.0
# 3          African Burial Ground NM      NaN        NaN        NaN        NaN
# 4              Agate Fossil Beds NM    16233    15235.0    14209.0    13521.0
# ..                              ...      ...        ...        ...        ...
# 384                      Wupatki NM   266159   247971.0   219480.0   236449.0
# 385                  Yellowstone NP  3019375  2868317.0  2835651.0  2870295.0
# 386                     Yosemite NP  3378664  3280911.0  3304144.0  3242644.0
# 387      Yukon-Charley Rivers NPRES     5552     4260.0    12784.0    12083.0
# 388                         Zion NP  2458792  2677342.0  2586665.0  2567350.0
#
# ...

# %% [markdown]
# visitors = visitors.drop(columns = [])

# %%
visitors.columns.to_list()
# Out:
# ['Park Name',
#  2003,
#  2004.0,
#  2005.0,
#  2006.0,
#  2007.0,
#  2008.0,
#  2009.0,
#  2010.0,
#  2011.0,
#  nan,
#  nan,
#  2012.0,
#  2013.0,
#  2014.0,
#  2015.0,
#  2016.0,
#  2017.0,
#  2018.0,
#  2019.0,
#  2020.0,
#  2021.0,
#  2022.0,
#  'Average']

# %%
visitors.columns = ['Park Name',
 '2003',
 '2004',
 '2005',
 '2006',
 '2007',
 '2008',
 '2009',
 '2010',
 '2011',
 'empty',
 'empty2',
 '2012',
 '2013',
 '2014',
 '2015',
 '2016',
 '2017',
 '2018',
 '2019',
 '2020',
 '2021',
 '2022',
 'Average']

# %%
visitors = visitors.drop(columns = ['empty', 'empty2'])

# %%
visitors
# Out:
#                           Park Name     2003       2004       2005       2006  \
# 0    Abraham Lincoln Birthplace NHP   211650   201828.0   190809.0   200054.0
# 1                         Acadia NP  2431062  2207847.0  2051484.0  2083588.0
# 2                         Adams NHP   215659   239504.0   220467.0   225318.0
# 3          African Burial Ground NM      NaN        NaN        NaN        NaN
# 4              Agate Fossil Beds NM    16233    15235.0    14209.0    13521.0
# ..                              ...      ...        ...        ...        ...
# 384                      Wupatki NM   266159   247971.0   219480.0   236449.0
# 385                  Yellowstone NP  3019375  2868317.0  2835651.0  2870295.0
# 386                     Yosemite NP  3378664  3280911.0  3304144.0  3242644.0
# 387      Yukon-Charley Rivers NPRES     5552     4260.0    12784.0    12083.0
# 388                         Zion NP  2458792  2677342.0  2586665.0  2567350.0
#
# ...

# %%
visitors.columns.to_list()
# Out:
# ['Park Name',
#  '2003',
#  '2004',
#  '2005',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '2010',
#  '2011',
#  '2012',
#  '2013',
#  '2014',
#  '2015',
#  '2016',
#  '2017',
#  '2018',
#  '2019',
#  '2020',
#  '2021',
#  '2022',
#  'Average']

# %% [markdown]
# visitors.to_csv('../data/visitors.csv', index = False)
